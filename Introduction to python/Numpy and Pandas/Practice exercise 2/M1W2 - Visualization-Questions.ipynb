# %% [markdown]
# # Q.1 Import the libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes = True)
# %matplotlib inline

# %% [markdown]
# # Q.2 Get the Dataset

# %%
a = pd.read_csv('tips.csv')

# %%
a.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Q3. Plot the distribution of total_bill in the given dataset.

# %%
sns.distplot(a['total_bill'])
# Out:
# /var/folders/lf/j6lhwfl96ssgpp9bdtfm9r640000gn/T/ipykernel_1313/4212233748.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Q.4 - Plot the destribution plot for tips.

# %%
sns.distplot(a['tip'])
# Out:
# /var/folders/lf/j6lhwfl96ssgpp9bdtfm9r640000gn/T/ipykernel_1313/4034800346.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Q5. Make a joint plot between tip and total bill.

# %%
sns.jointplot(x=a['total_bill'],y=a['tip']);

# %% [markdown]
# # Q6. Give additional attribute kind = "hex" in the above plot.

# %%
sns.jointplot(x=a['total_bill'],y=a['tip'],kind="hex");

# %% [markdown]
# # Q7. Make pairplot between total bill and tip.

# %%
sns.pairplot(a[['total_bill','tip']]);

# %% [markdown]
# # Q.8 -  Make striplot between sex and tip.

# %%
sns.stripplot(x=a['sex'],y=a['tip'],jitter = True);

# %% [markdown]
# # Q.9 - What other plots you can make for tip and sex variable.Plot them.

# %%
sns.swarmplot(x=a['sex'],y=a['tip']);

# %% [markdown]
# # Q.10 Make bar plot with day and total bill.

# %%
sns.barplot(x=a['day'],y=a['total_bill']);

# %% [markdown]
# # Q.11 - Make a plot to count total males and females for each day.

# %%
sns.countplot(x=a['day'], hue = a['sex']);

# %% [markdown]
# # Q.12 -  Use factorplot to plot multiple categorical variables like day, smoker, peoplecount.

# %%
sns.catplot(
    x="day",
    y="size",
    hue="size",
    col="smoker",
    data=a,
    kind="bar"
)

# %% [markdown]
# # Q.13 - Use lmplot() to plot the relation between total bill and tip.

# %%
sns.lmplot(x = "total_bill",
               y = "tip", data = a);

# %% [markdown]
# # Q.14 - Plot the above graph for male and female.

# %%
sns.lmplot(x = "total_bill",
               y = "tip", data = a, hue = "sex");

# %% [markdown]
# # Q.14 - Plot the Q.13 graph for smoker and non-smoker.

# %%
 sns.lmplot(x = "total_bill",
               y = "tip", data = a, hue = "smoker");
